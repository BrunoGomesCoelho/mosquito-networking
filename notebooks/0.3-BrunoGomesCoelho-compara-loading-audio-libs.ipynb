# %%
from scipy.io import wavfile
fs, data = wavfile.read("../data/raw/dadosBruno/t02/t02_S-ISCA_C1_Aedes female-20-07-2017_1_001_456.wav")
print("Sampling rate", fs)
len(data)
# Out:
# Sampling rate 44100
# 13486

# %%
print(len(data)/fs)
# Out:
# 0.3058049886621315

# %% [markdown]
# This should be ~0.3 seconds.
#
# Same thing as `mediainfo --Inform="Audio;%Duration%" "../data/raw/dadosBruno/t02/t02_S-ISCA_C1_Aedes female-20-07-2017_1_001_456.wav"`

# %%
sns.timeseries.plt.plot(data)

# %%
data.dtype
# Out:
# dtype('int16')

# %%
import librosa

# %%
# %%timeit
t1, t2 = librosa.load("../data/raw/dadosBruno/t02/t02_S-ISCA_C1_Aedes female-20-07-2017_1_001_456.wav",
                     sr=44100)
# Out:
# 179 µs ± 2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
fs, data = wavfile.read("../data/raw/dadosBruno/t02/t02_S-ISCA_C1_Aedes female-20-07-2017_1_001_456.wav")
# Out:
# 44.5 µs ± 761 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import IPython
IPython.display.Audio(data, rate=44100)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(t1, rate=44100)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Scipy loads as ints and librosa as floats.
#
# Scipy is 4x time faster.
#
# See [here](https://stackoverflow.com/questions/50062358/difference-between-load-of-librosa-and-read-of-scipy-io-wavfile)

# %%
from src.data.read_dataset import read_all_wavs

# %%
read_all_wavs("../data/raw/dadosBruno/")
# Out:
# array([[44100, array([14, 12,  7, ..., 22, 19, 13], dtype=int16)],
#        [44100,
#         array([  39,   42,   10, ..., -166, -115, -363], dtype=int16)],
#        [44100,
#         array([-104, -121,  -98, ...,   21,   22,   14], dtype=int16)],
#        ...,
#        [44100, array([207, 234, 251, ...,  45,  72, 110], dtype=int16)],
#        [44100, array([ -3,  -7, -12, ..., -79, -82, -61], dtype=int16)],
#        [44100,
#         array([ -92,  -73,  -38, ..., 2052, 2243, 2395], dtype=int16)]],
#       dtype=object)
